# %% [markdown]
# # SPCA test notebook

# %% [markdown]
# ## Pitprops dataset

# %%
# evaluate an elastic net model on the dataset
from scipy.linalg import sqrtm
import numpy as np
from pandas import read_csv
from SPCA import SPCA
from numpy.linalg import qr
# load the dataset
path = 'data/Optimal-SPCA/Data/pitprops.csv'
dataframe = read_csv(path, header=None)
data = dataframe.values
X = sqrtm(data)
X
#X, y = data[:, :-1], data[:, -1]
# define model
#model = ElasticNet(alpha=1.0, l1_ratio=0.5)
# define model evaluation method
#cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
#scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
#scores = absolute(scores)
#print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# array([[ 0.71968034,  0.51246897,  0.15403456,  0.13011106, -0.07510741,
#          0.10390403,  0.18568679,  0.16090098,  0.20948399,  0.21414269,
#          0.04669265,  0.01455327,  0.0992054 ],
#        [ 0.51246897,  0.71537645,  0.10681558,  0.09631948, -0.06242119,
#          0.08638421,  0.18877563,  0.1411759 ,  0.26626303,  0.22945159,
#          0.0450387 ,  0.00757406,  0.11121908],
#        [ 0.15403456,  0.10681558,  0.79978961,  0.53694298, -0.11577395,
#          0.04982259, -0.05340022, -0.02589523,  0.03746204, -0.05037404,
#          0.06592947,  0.08622998,  0.0419679 ],
#        [ 0.13011106,  0.09631948,  0.53694298,  0.7864407 ,  0.15584267,
#          0.17389014,  0.05023782, -0.04590506,  0.03935058, -0.02486322,
#          0.03263293,  0.06785304,  0.00234819],
#        [-0.07510741, -0.06242119, -0.11577395,  0.15584267,  0.94702001,
#          0.16354665,  0.12918696,  0.00221619, -0.02139947, -0.00455828,
#         -0.03964602, -0.07120487, -0.07323033],
# ...

# %%
X,V,Z = SPCA(X,k=11,max_iter=100,alpha=0.006,verbose=True)
# Out:
# ('SPCA',)
# ('- Initialization',)
# ('-- n:', 13, 'p:', 13, 'k:', 11)
# ('-- V0:', 13, 'x', 11)
# ('-- A0:', 13, 'x', 11)
# (array([[-0.28633464, -0.31120406,  0.23952909,  0.23004107,  0.0300361 ,
#         -0.12573116, -0.37798876, -0.31445375, -0.30364431, -0.44004313,
#          0.16241013],
#        [-0.37875683, -0.38014472, -0.17390726,  0.05263982,  0.46912563,
#          0.43243618,  0.32518609, -0.07125335, -0.1835281 ,  0.00960528,
#         -0.09547144],
#        [ 0.26759596,  0.2056041 ,  0.54234242,  0.58105967, -0.09866591,
#          0.29714012,  0.17851863, -0.21958243, -0.02569971,  0.04510355,
#         -0.19530629],
#        [-0.12395811, -0.15164392,  0.25985194,  0.22289145,  0.00354819,
#         -0.16445051, -0.10434355,  0.39076922,  0.16205696, -0.07124502,
#          0.56201051],
#        [ 0.11228679,  0.11678318, -0.13445891, -0.23268014, -0.34388579,
#          0.35224396,  0.2138451 , -0.21450487,  0.07876085, -0.24627124,
#          0.55268599],
# ...

# %%
assert(False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 assert(False)
#
# AssertionError:

# %%
k=6
lambda_l1_range=[0.06, 0.16, 0.1, 0.5, 0.5, 0.5]

for lambda_l1 in lambda_l1_range:
    X_prime,V,Z = SPCA(X,k=k,max_iter=100,alpha=lambda_l1,verbose=False)
    #print(X)
    #print(X_prime)
    # Compute adjusted total variance
    Q,R = qr(Z)
    adj_total_variance=0.0
    for idx in range(k):
        adj_total_variance += R[idx,idx]**2
    print("Adjusted total variance, lambda_l1=",lambda_l1,":",adj_total_variance)
